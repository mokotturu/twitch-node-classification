# %%
from pprint import pprint

import numpy as np
import pandas as pd

# %%
df = pd.read_csv('transferability_report.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
de_f1 = df.loc[0:5, 'F1-Score']
de_f1 = np.array([float(i) for i in de_f1 if i != '-'])
print(f'Mean F-1 Score for DE model: {np.mean(de_f1)}')
df[0:6]
# Out:
# Mean F-1 Score for DE model: 0.525348836885157
#   Trained-Tested            Accuracy           Precision              Recall  \
# 0          DE-DE                   -                   -                   -
# 1          DE-EN    0.56286836935167  0.5952548926589774    0.56286836935167
# 2          DE-ES   0.705895008605852   0.678717978691455   0.705895008605852
# 3          DE-FR   0.386658525415967  0.5745852403270474   0.386658525415967
# 4          DE-PT  0.6501046025104602  0.5704978311829104  0.6501046025104602
# 5          DE-RU  0.5735461801596351   0.672171506059991  0.5735461801596351
#
#              F1-Score
# 0                   -
# 1  0.5511200497853775
# 2  0.6838415774491357
# 3  0.2575004428764135
# 4  0.5316024682461992
# 5  0.6026796460686593

# %%
en_f1 = df.loc[6:11, 'F1-Score']
en_f1 = np.array([float(i) for i in en_f1 if i != '-'])
print(f'Mean F-1 Score for EN model: {np.mean(en_f1)}')
df[6:12]
# Out:
# Mean F-1 Score for EN model: 0.5640909587742091
#    Trained-Tested            Accuracy           Precision              Recall  \
# 6           EN-DE  0.6540324278795536  0.6540791860083839  0.6540324278795536
# 7           EN-EN                   -                   -                   -
# 8           EN-ES  0.6908347676419966  0.6173456308952702  0.6908347676419966
# 9           EN-FR  0.4464967180583117  0.5580451918520689  0.4464967180583117
# 10          EN-PT  0.6380753138075314  0.5337217713010564  0.6380753138075314
# 11          EN-RU  0.6346636259977195   0.659374141828006  0.6346636259977195
#
#               F1-Score
# 6   0.6090570562545184
# 7                    -
# 8   0.6174254455788366
# 9   0.4177127051499851
# 10  0.5306774799149663
# 11  0.6455821069727387

# %%
es_f1 = df.loc[12:17, 'F1-Score']
es_f1 = np.array([float(i) for i in es_f1 if i != '-'])
print(f'Mean F-1 Score for ES model: {np.mean(es_f1)}')
df[12:18]
# Out:
# Mean F-1 Score for ES model: 0.43270057501424325
#    Trained-Tested             Accuracy            Precision  \
# 12          ES-DE   0.3954516740366393   0.3954516740366393
# 13          ES-EN  0.45439236598372157  0.45439236598372157
# 14          ES-ES                    -                    -
# 15          ES-FR   0.6312013433063655   0.6312013433063655
# 16          ES-PT   0.6542887029288703   0.6542887029288703
# 17          ES-RU   0.7548460661345496   0.7548460661345496
#
#                  Recall             F1-Score
# 12   0.3954516740366393  0.22413105291709928
# 13  0.45439236598372157   0.2839294637312409
# 14                    -                    -
# 15   0.6312013433063655   0.4884928981044023
# 16   0.6542887029288703   0.5175562234359891
# 17   0.7548460661345496   0.6493932368824845

# %%
fr_f1 = df.loc[18:23, 'F1-Score']
fr_f1 = np.array([float(i) for i in fr_f1 if i != '-'])
print(f'Mean F-1 Score for FR model: {np.mean(fr_f1)}')
df[18:24]
# Out:
# Mean F-1 Score for FR model: 0.4522366020226449
#    Trained-Tested             Accuracy            Precision  \
# 18          FR-DE   0.3954516740366393   0.3954516740366393
# 19          FR-EN  0.45439236598372157  0.45439236598372157
# 20          FR-ES   0.7074010327022375   0.7074010327022375
# 21          FR-FR                    -                    -
# 22          FR-PT   0.6542887029288703   0.6542887029288703
# 23          FR-RU   0.7548460661345496   0.7548460661345496
#
#                  Recall             F1-Score
# 18   0.3954516740366393  0.22413105291709928
# 19  0.45439236598372157   0.2839294637312409
# 20   0.7074010327022375   0.5861730331464106
# 21                    -                    -
# 22   0.6542887029288703   0.5175562234359891
# 23   0.7548460661345496   0.6493932368824845

# %%
pt_f1 = df.loc[24:29, 'F1-Score']
pt_f1 = np.array([float(i) for i in pt_f1 if i != '-'])
print(f'Mean F-1 Score for PT model: {np.mean(pt_f1)}')
df[24:30]
# Out:
# Mean F-1 Score for PT model: 0.44642393695632754
#    Trained-Tested             Accuracy            Precision  \
# 24          PT-DE   0.3954516740366393   0.3954516740366393
# 25          PT-EN  0.45439236598372157  0.45439236598372157
# 26          PT-ES   0.7074010327022375   0.7074010327022375
# 27          PT-FR   0.6312013433063655   0.6312013433063655
# 28          PT-PT                    -                    -
# 29          PT-RU   0.7548460661345496   0.7548460661345496
#
#                  Recall             F1-Score
# 24   0.3954516740366393  0.22413105291709928
# 25  0.45439236598372157   0.2839294637312409
# 26   0.7074010327022375   0.5861730331464106
# 27   0.6312013433063655   0.4884928981044023
# 28                    -                    -
# 29   0.7548460661345496   0.6493932368824845

# %%
ru_f1 = df.loc[30:35, 'F1-Score']
ru_f1 = np.array([float(i) for i in ru_f1 if i != '-'])
print(f'Mean F-1 Score for RU model: {np.mean(ru_f1)}')
df[30:36]
# Out:
# Mean F-1 Score for RU model: 0.42005653426702844
#    Trained-Tested             Accuracy            Precision  \
# 30          RU-DE   0.3954516740366393   0.3954516740366393
# 31          RU-EN  0.45439236598372157  0.45439236598372157
# 32          RU-ES   0.7074010327022375   0.7074010327022375
# 33          RU-FR   0.6312013433063655   0.6312013433063655
# 34          RU-PT   0.6542887029288703   0.6542887029288703
# 35          RU-RU                    -                    -
#
#                  Recall             F1-Score
# 30   0.3954516740366393  0.22413105291709928
# 31  0.45439236598372157   0.2839294637312409
# 32   0.7074010327022375   0.5861730331464106
# 33   0.6312013433063655   0.4884928981044023
# 34   0.6542887029288703   0.5175562234359891
# 35                    -                    -

# %%
df2 = pd.read_csv('metrics_report.csv')
df2 = df2.loc[:, ~df2.columns.str.contains('^Unnamed')]
df2
# Out:
#   Trained-Tested  Accuracy  Precision    Recall  F1-Score
# 0          DE-DE  0.705412   0.700601  0.705412  0.700729
# 1          EN-EN  0.703059   0.706537  0.703059  0.696780
# 2          ES-ES  0.707401   0.707401  0.707401  0.586173
# 3          FR-FR  0.631201   0.631201  0.631201  0.488493
# 4          PT-PT  0.654289   0.654289  0.654289  0.517556
# 5          RU-RU  0.754846   0.754846  0.754846  0.649393
